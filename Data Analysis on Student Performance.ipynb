# %% [markdown]
# # Data Analysis on Student Performance Dataset

# %% [markdown]
# ## Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importing Dataset

# %%
sp=pd.read_csv("StudentsPerformance.csv")

# %%
sp
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
sp.head()
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75

# %% [markdown]
# # 1.Data Understanding

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# **• Gender:** The gender of the student (male/female)
#
# **• Race/ethnicity:** The student's racial or ethnic background (Asian, African-American, Hispanic, etc.)
#
# **• Parental level of education:** The highest level of education attained by the student's parent(s) or guardian(s)
#
# **• Lunch:** Whether the student receives free or reduced-price lunch (yes/no)
#
# **• Test preparation course:** Whether the student completed a test preparation course (yes/no)
#
# **• Math score:** The student's score on a standardized mathematics test
#
# **• Reading score:** The student's score on a standardized reading test
#
# **• Writing score:** The student's score on a standardized writing test

# %% [markdown]
# # 2.Initial Checkup

# %%
sp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   gender                       1000 non-null   object
#  1   race/ethnicity               1000 non-null   object
#  2   parental level of education  1000 non-null   object
#  3   lunch                        1000 non-null   object
#  4   test preparation course      1000 non-null   object
#  5   math score                   1000 non-null   int64
#  6   reading score                1000 non-null   int64
#  7   writing score                1000 non-null   int64
# dtypes: int64(3), object(5)
# memory usage: 62.6+ KB

# %% [markdown]
# # 3.Asking Questions to the Data

# %%
# 1.which gender got highest math score?
# 2.which gender got highest math score?
# 3.which gender got highest reading score?
# 4.which gender got highest writing score?
# 5.how many student's parents have degree?
# 6.which gender got highest reading score?

# %% [markdown]
# # 4.Univariate Analysis

# %%
sp['gender'].value_counts()
# Out:
# female    518
# male      482
# Name: gender, dtype: int64

# %%
# female students are more in number than male students

# %%
sns.countplot(sp,x='gender')
# Out:
# <Axes: xlabel='gender', ylabel='count'>

# %%
sp['gender'].value_counts(normalize=True)*100
# Out:
# female    51.8
# male      48.2
# Name: gender, dtype: float64

# %%
# 51.8% students are female
# 48.2% students are male

# %%
sp['race/ethnicity'].value_counts(ascending=True)
# Out:
# group A     89
# group E    140
# group B    190
# group D    262
# group C    319
# Name: race/ethnicity, dtype: int64

# %%
# group C students are more in number
# group A students are less in number

# %%
sns.countplot(sp,x='race/ethnicity')
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='count'>

# %%
sp['race/ethnicity'].value_counts(normalize=True,ascending=True)*100
# Out:
# group A     8.9
# group E    14.0
# group B    19.0
# group D    26.2
# group C    31.9
# Name: race/ethnicity, dtype: float64

# %%
# 31.9% students are belong to group C
# 26.2% students are belong to group D
# 19% students are belong to group B
# 14% students are belong to group E
# 8.9% students are belong to group A

# %%
sp['parental level of education'].value_counts()
# Out:
# some college          226
# associate's degree    222
# high school           196
# some high school      179
# bachelor's degree     118
# master's degree        59
# Name: parental level of education, dtype: int64

# %%
plt.figure(figsize=(10,6))
sns.countplot(sp,x='parental level of education')
# Out:
# <Axes: xlabel='parental level of education', ylabel='count'>

# %%
# 22.6% of student parents are studied untill college
# only 5.9% of student parents having master's degree

# %%
sp['parental level of education'].value_counts(normalize=True)*100
# Out:
# some college          22.6
# associate's degree    22.2
# high school           19.6
# some high school      17.9
# bachelor's degree     11.8
# master's degree        5.9
# Name: parental level of education, dtype: float64

# %%
sp['lunch'].value_counts()
# Out:
# standard        645
# free/reduced    355
# Name: lunch, dtype: int64

# %%
sns.countplot(sp,x='lunch')
# Out:
# <Axes: xlabel='lunch', ylabel='count'>

# %%
sp['lunch'].value_counts(normalize=True)*100
# Out:
# standard        64.5
# free/reduced    35.5
# Name: lunch, dtype: float64

# %%
sp['test preparation course'].value_counts()
# Out:
# none         642
# completed    358
# Name: test preparation course, dtype: int64

# %%
sns.countplot(sp,x='test preparation course')
# Out:
# <Axes: xlabel='test preparation course', ylabel='count'>

# %%
sp['test preparation course'].value_counts(normalize=True)*100
# Out:
# none         64.2
# completed    35.8
# Name: test preparation course, dtype: float64

# %%
# 64.2% of students did not complete test preparation course
# 35.8% of students are completed their test preparation course

# %%
sp['math score'].describe()
# Out:
# count    1000.00000
# mean       66.08900
# std        15.16308
# min         0.00000
# 25%        57.00000
# 50%        66.00000
# 75%        77.00000
# max       100.00000
# Name: math score, dtype: float64

# %%
# average math score of the students is 66
# highest math score of the students is 100
# lowest math score of the students is 0

# %%
sns.histplot(sp,x='math score')
# Out:
# <Axes: xlabel='math score', ylabel='Count'>

# %%
sns.kdeplot(sp,x='math score')
# Out:
# <Axes: xlabel='math score', ylabel='Density'>

# %%
sp['reading score'].describe()
# Out:
# count    1000.000000
# mean       69.169000
# std        14.600192
# min        17.000000
# 25%        59.000000
# 50%        70.000000
# 75%        79.000000
# max       100.000000
# Name: reading score, dtype: float64

# %%
sns.histplot(sp,x='reading score')
# Out:
# <Axes: xlabel='reading score', ylabel='Count'>

# %%
sns.kdeplot(sp,x='reading score')
# Out:
# <Axes: xlabel='reading score', ylabel='Density'>

# %%
# average reading score of the students is 69
# highest reading score of the students is 100
# lowest reading score of the students is 17 
# standard deviation of the reading score is 14 that means most of the students got marks between 55 and 83

# %%
sp['writing score'].describe()
# Out:
# count    1000.000000
# mean       68.054000
# std        15.195657
# min        10.000000
# 25%        57.750000
# 50%        69.000000
# 75%        79.000000
# max       100.000000
# Name: writing score, dtype: float64

# %%
sns.histplot(sp,x='writing score')
# Out:
# <Axes: xlabel='writing score', ylabel='Count'>

# %%
sns.kdeplot(sp,x='writing score')
# Out:
# <Axes: xlabel='writing score', ylabel='Density'>

# %%
# average writing score of the students is 68
# highest writing score of the students is 100
# lowest writing score of the students is 10 
# standard deviation of the writing score is 15 that means most of the students got marks between 53 and 83

# %%
sns.countplot(sp,x='test preparation course',hue='gender')
# Out:
# <Axes: xlabel='test preparation course', ylabel='count'>

# %%
# more female students are completed their course than male

# %%
sns.countplot(sp,x='race/ethnicity',hue='gender')
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='count'>

# %%
# group C has highest number of female students
# group D has highest number of male students

# %%
sns.countplot(sp,x='race/ethnicity',hue='test preparation course')
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='count'>

# %%
# in group C more students did not complete the course

# %%
plt.figure(figsize=(10,6))
sns.countplot(sp,x='parental level of education',hue='gender')
# Out:
# <Axes: xlabel='parental level of education', ylabel='count'>

# %%
# more female student parents have associate's degree

# %%
sns.countplot(sp,x='lunch',hue='gender')
# Out:
# <Axes: xlabel='lunch', ylabel='count'>

# %%
# more female students fees has been reduced than male students

# %% [markdown]
# # 5.Bivariate Analysis

# %%
plt.figure(figsize=(8,6))
sns.swarmplot(sp,x='gender',y='math score')
plt.title("Gender wise math score of students")
# Out:
# Text(0.5, 1.0, 'Gender wise math score of students')

# %%
plt.figure(figsize=(10,6))
sns.swarmplot(sp,x='race/ethnicity',y='math score',hue='gender')
plt.title("Race wise math score of male and female students")
# Out:
# Text(0.5, 1.0, 'Race wise math score of male and female students')

# %%
sns.lineplot(sp,x='reading score',y='math score')
# Out:
# <Axes: xlabel='reading score', ylabel='math score'>

# %%
sns.lineplot(sp,x='reading score',y='math score',hue='gender')
# Out:
# <Axes: xlabel='reading score', ylabel='math score'>

# %%
plt.figure(figsize=(10,6))
sns.stripplot(sp,x='parental level of education',y='reading score')
# Out:
# <Axes: xlabel='parental level of education', ylabel='reading score'>

# %%
plt.figure(figsize=(10,6))
sns.stripplot(sp,x='parental level of education',y='reading score',hue='gender')
# Out:
# <Axes: xlabel='parental level of education', ylabel='reading score'>

# %%
plt.figure(figsize=(10,6))
sns.barplot(sp,x='parental level of education',y='reading score')
# Out:
# <Axes: xlabel='parental level of education', ylabel='reading score'>

# %%
plt.figure(figsize=(10,6))
sns.barplot(sp,x='parental level of education',y='reading score',hue='gender')
# Out:
# <Axes: xlabel='parental level of education', ylabel='reading score'>

# %%
sns.barplot(sp,x='race/ethnicity',y='writing score')
# Out:
# <Axes: xlabel='race/ethnicity', ylabel='writing score'>

# %%
sns.barplot(sp,x='lunch',y='writing score',hue='gender')
# Out:
# <Axes: xlabel='lunch', ylabel='writing score'>

# %%
sns.barplot(sp,x='gender',y='math score')
# Out:
# <Axes: xlabel='gender', ylabel='math score'>

# %%
# male students got highest math score

# %%
sns.barplot(sp,x='gender',y='reading score')
# Out:
# <Axes: xlabel='gender', ylabel='reading score'>

# %%
# female students got highest reading score

# %%
sns.barplot(sp,x='gender',y='writing score')
# Out:
# <Axes: xlabel='gender', ylabel='writing score'>

# %%
# female students got highest writing score

# %% [markdown]
# # 6.Summary

# %%
'''female students are more in number than male students
    51.8% students are female
    48.2% students are male
    group C students are more in number
    group A students are less in number
    31.9% students are belong to group C
    26.2% students are belong to group D
    19% students are belong to group B
    14% students are belong to group E
    8.9% students are belong to group A
    22.6% of student parents are studied untill college
    only 5.9% of student parents having master's degree
    64.2% of students did not complete test preparation course
    35.8% of students are completed their test preparation course
    average math score of the students is 66
    highest math score of the students is 100
    lowest math score of the students is 0
    average reading score of the students is 69
    highest reading score of the students is 100
    lowest reading score of the students is 17 
    standard deviation of the reading score is 14 that means most of the students got marks between 55 and 83
    average writing score of the students is 68
    highest writing score of the students is 100
    lowest writing score of the students is 10 
    standard deviation of the writing score is 15 that means most of the students got marks between 53 and 83
    more female students are completed their course than male
    male students got highest math score
    female students got highest reading score
    female students got highest writing score'''
